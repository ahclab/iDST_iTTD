# %%
import numpy as np
import plotly
import logging
logging.getLogger().setLevel(logging.INFO)

from idst_util import trivial
from idst_util import dstc2
from operator import itemgetter
from plotly.graph_objs import Scatter, Bar, Layout, Margin
plotly.offline.init_notebook_mode(connected = True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Make sure data is available
trivial.print_idst()
dstc2.check()

# Retrieve raw data
raw_X_train, raw_Y_train, \
raw_X_dev, raw_Y_dev, \
raw_X_test, raw_Y_test, \
ontology = dstc2.retrieve_raw_datasets(train_data_augmentation = False)
# Out:
# INFO:root:+--------------------------------+
# INFO:root:|         _ ____  ___________    |
# INFO:root:|        (_) __ \/ ___/_  __/    |
# INFO:root:|       / / / / /\__ \ / /       |
# INFO:root:|      / / /_/ /___/ // /        |
# INFO:root:|     /_/_____//____//_/         |
# INFO:root:|                                |
# INFO:root:+--------------------------------+
# INFO:root:|Incremental Dialog State Tracker|
# INFO:root:+--------------------------------+
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|         Data Checker           |
# INFO:root:+--------------------------------+
# INFO:root:Looking for dstc2 directory in .
# INFO:root:dstc2 was found!
# INFO:root:Looking for dstc2_traindev directory in ./dstc2
# INFO:root:dstc2_traindev was found!
# INFO:root:Looking for dstc2_test directory in ./dstc2
# INFO:root:dstc2_test was found!
# INFO:root:Looking for dstc2_scripts directory in ./dstc2
# INFO:root:dstc2_scripts was found!
# INFO:root:Done!
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|       Dataset Retrieval        |
# INFO:root:+--------------------------------+
# INFO:root:Reading dstc2_train.flist, dstc2_dev.flist and ontology_dstc2.json
# INFO:root:Asserted 1612 dialogs for dstc2_train.flist
# INFO:root:Asserted 506 dialogs for dstc2_dev.flist
# INFO:root:Extracting raw train features
# 100%|██████████| 1612/1612 [00:05<00:00, 303.09it/s]
# INFO:root:Extracting raw dev features
# 100%|██████████| 506/506 [00:01<00:00, 287.08it/s]
# INFO:root:Reading dstc2_test.flist
# INFO:root:Asserted 1117 dialogs for dstc2_test.flist
# INFO:root:Extracting raw test features
# 100%|██████████| 1117/1117 [00:04<00:00, 278.14it/s]

# %%
def retrieve_info(raw_X):
    
    token_to_count = {}
    max_sequence_length = 0
    turns_list = []
    
    for raw_dialog in raw_X:
        turns_count = 0
        for raw_turn in raw_dialog:
            turns_count += 1
            current_sequence_length = len(raw_turn["system"]) + len(raw_turn["user"])
            if current_sequence_length > max_sequence_length:
                max_sequence_length = current_sequence_length

            for system_token in raw_turn["system"]:
                token = system_token[0]
                if token not in token_to_count:
                    token_to_count[token] = 1
                else:
                    token_to_count[token] += 1

            for user_token in raw_turn["user"]:
                token = user_token[0]
                if token not in token_to_count:
                    token_to_count[token] = 1
                else:
                    token_to_count[token] += 1
            turns_list.append(turns_count)
    
    return token_to_count, max_sequence_length, np.mean(turns_list)

# %%
train_vocabulary, \
train_max_sequence_length, \
train_average_turns_per_dialog = retrieve_info(raw_X_train)


dev_vocabulary, \
dev_max_sequence_length, \
dev_average_turns_per_dialog = retrieve_info(raw_X_dev)

test_vocabulary, \
test_max_sequence_length, \
test_average_turns_per_dialog = retrieve_info(raw_X_test)

# %%
logging.info("+--------------------------------+")
logging.info("|     Dialog State Tracker 2     |")
logging.info("|         Data Analysis          |")
logging.info("+--------------------------------+\n")

logging.info("Train number of dialogs:\t{}".format(len(raw_X_train)))
logging.info("Train vocabulary length:\t{}".format(len(train_vocabulary)))
logging.info("Train max sequence length:\t{}".format(train_max_sequence_length))
logging.info("Train average turns:\t\t{}\n".format(train_average_turns_per_dialog))

logging.info("Dev number of dialogs:\t{}".format(len(raw_X_dev)))
logging.info("Dev vocabulary length:\t{}".format(len(dev_vocabulary)))
logging.info("Dev max sequence length:\t{}".format(dev_max_sequence_length))
logging.info("Dev average turns:\t\t{}\n".format(dev_average_turns_per_dialog))

logging.info("Test number of dialogs:\t{}".format(len(raw_X_test)))
logging.info("Test vocabulary length:\t{}".format(len(test_vocabulary)))
logging.info("Test max sequence length:\t{}".format(test_max_sequence_length))
logging.info("Test average turns:\t\t{}\n".format(test_average_turns_per_dialog))
# Out:
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|         Data Analysis          |
# INFO:root:+--------------------------------+
#
# INFO:root:Train number of dialogs:	1612
# INFO:root:Train vocabulary length:	928
# INFO:root:Train max sequence length:	27
# INFO:root:Train average turns:		4.930461591162113
#
# INFO:root:Dev number of dialogs:	506
# INFO:root:Dev vocabulary length:	771
# INFO:root:Dev max sequence length:	28
# INFO:root:Dev average turns:		5.454499237417387
#
# INFO:root:Test number of dialogs:	1117
# INFO:root:Test vocabulary length:	911
# INFO:root:Test max sequence length:	33
# INFO:root:Test average turns:		5.983923154701719

# %%
train_X_axis = []
train_Y_axis = []
train_top_tokens = []
sorted_dict = sorted(train_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(train_top_tokens) <= 10:
        train_top_tokens.append((token, token_count))
    if token_count > 50:
        train_X_axis.append(token)
        train_Y_axis.append(token_count)

assert(len(train_X_axis) == len(train_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = train_X_axis,
                 y = train_Y_axis,
                 marker = dict(color = "#1abc9c"))],
    "layout": Layout(title = "<b>Train tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#1abc9c")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#1abc9c")),
                     margin = plotly.graph_objs.layout.Margin(b = 150)
                    )
})

logging.info("Train top tokens:\t{}".format(train_top_tokens))
# Out:
# <div id="3593215e-d54c-44ae-b7e3-ec90403b7842" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3593215e-d54c-44ae-b7e3-ec90403b7842", [{"marker": {"color": "#1abc9c"}, "orientation": "v", "x": ["inform", "name", "offer", "food", "the", "area", "pricerange", "phone", "restaurant", "request", "slot", "you", "thank", "welcomemsg", "number", "canthelp", "address", "i", "addr", "of", "cheap", "01223", "goodbye", "a", "and", "expensive", "centre", "what", "moderate", "in", "north", "is", "south", "part", "town", "for", "looking", "west", "east", "good", "city", "i'm", "bye", "what's", "expl-conf", "road", "about", "that", "don't", "can", "street", "bar", "care", "chinese", "indian", "yes", "cherry", "any", "hinton", "pizza", "post", "serves", "code", "ok", "moderately", "how", "european", "price", "have", "la", "cambridge", "priced", "postcode", "c.b", "it", "hut", "royal", "house", "anything", "type", "thanh", "binh", "there", "italian", "else", "range", "select", "nandos", "fen", "ditton", "chesterton", "pizzeria", "want", "tandoori", "okay", "saint", "missing", "sock", "da", "vinci", "no", "british", "two", "spice", "asian", "curry", "park", "chop", "little", "johns", "uh", "hotel", "doesn't", "lucky", "star", "matter", "dontcare", "please", "seoul", "prezzo", "turkish", "like", "golden", "oriental", "leisure", "korean", "to", "alimentum", "meghna", "chiquito", "wok", "kitchen", "newmarket", "vietnamese", "portuguese", "garden", "french", "-", "clifton", "way", "2", "prince", "margherita", "serve", "find", "bistro", "spanish", "modern", "thai", "international", "noodle", "mediterranean", "sala", "thong", "hi", "grafton", "um", "peking", "gastropub", "serving", "rajmahal", "cafe", "nirala", "yu", "standard", "frankie", "bennys", "michaelhouse", "need", "am", "get", "tasca", "1", "lodge", "regent", "kind", "reqmore", "canthelp.exception", "confirm-domain", "greek", "24", "gourmet", "burger", "saigon", "world", "american", "luck", "takeaway", "does", "do", "would", "sitar", "anatolia", "bridge", "pipasha", "cote", "an", "taj", "cow", "victoria", "raza", "21", "meze", "magdalene", "northampton", "fusion", "mexican", "cantonese", "may", "milton", "i'd", "gardenia", "mill", "wagamama", "bangkok", "could", "corsica", "me", "danish", "english", "their", "pub", "varsity"], "y": [7936, 6162, 6077, 5331, 3596, 3261, 2584, 2571, 2353, 1910, 1910, 1831, 1640, 1612, 1402, 1286, 1258, 1235, 1168, 1139, 1128, 1108, 1039, 999, 992, 949, 923, 923, 917, 898, 867, 844, 804, 760, 754, 746, 731, 698, 668, 661, 619, 611, 598, 578, 505, 501, 484, 477, 451, 446, 445, 434, 421, 399, 387, 384, 369, 354, 354, 350, 347, 346, 343, 336, 331, 328, 325, 315, 312, 308, 307, 298, 296, 296, 287, 272, 270, 267, 255, 255, 253, 253, 250, 248, 247, 240, 240, 238, 225, 225, 216, 216, 204, 202, 196, 195, 195, 195, 194, 192, 187, 186, 182, 181, 180, 180, 176, 173, 169, 169, 168, 164, 162, 162, 162, 161, 161, 161, 160, 160, 157, 156, 156, 154, 154, 150, 148, 147, 141, 139, 139, 138, 133, 133, 131, 129, 128, 126, 125, 125, 124, 122, 118, 117, 115, 115, 114, 114, 112, 105, 104, 104, 101, 101, 101, 100, 98, 97, 96, 96, 93, 92, 92, 89, 89, 88, 88, 88, 87, 87, 83, 81, 81, 81, 80, 80, 79, 79, 78, 78, 75, 75, 75, 74, 73, 73, 73, 73, 72, 71, 69, 68, 68, 67, 66, 65, 64, 63, 63, 62, 61, 61, 61, 60, 60, 60, 59, 58, 58, 56, 56, 55, 55, 55, 55, 54, 54, 53, 53, 52, 52, 52, 52], "type": "bar", "uid": "095ec387-1a94-4be3-8998-88a2d0e6026d"}], {"margin": {"b": 150}, "title": "<b>Train tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#1abc9c"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#1abc9c"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window ...
# INFO:root:Train top tokens:	[('inform', 7936), ('name', 6162), ('offer', 6077), ('food', 5331), ('the', 3596), ('area', 3261), ('pricerange', 2584), ('phone', 2571), ('restaurant', 2353), ('request', 1910), ('slot', 1910)]

# %%
dev_X_axis = []
dev_Y_axis = []
dev_top_tokens = []
sorted_dict = sorted(dev_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(dev_top_tokens) <= 10:
        dev_top_tokens.append((token, token_count))
    if token_count > 20:
        dev_X_axis.append(token)
        dev_Y_axis.append(token_count)

assert(len(dev_X_axis) == len(dev_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = dev_X_axis,
                 y = dev_Y_axis,
                 marker = dict(color = "#3498db"))],
    "layout": Layout(title = "<b>Dev tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#3498db")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#3498db")),
                     margin = plotly.graph_objs.layout.Margin(b = 150)
                    )
})


logging.info("Dev top tokens:\t{}".format(dev_top_tokens))
# Out:
# <div id="598d83d8-9e1f-4e45-a167-00829ab0a1a7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("598d83d8-9e1f-4e45-a167-00829ab0a1a7", [{"marker": {"color": "#3498db"}, "orientation": "v", "x": ["inform", "name", "offer", "food", "the", "area", "pricerange", "phone", "restaurant", "request", "slot", "you", "thank", "welcomemsg", "canthelp", "i", "number", "of", "cheap", "address", "addr", "and", "is", "01223", "goodbye", "what", "a", "in", "north", "centre", "town", "part", "expensive", "for", "moderate", "south", "looking", "east", "good", "west", "city", "i'm", "expl-conf", "bye", "can", "what's", "don't", "any", "road", "yes", "street", "ok", "about", "price", "la", "bar", "that", "care", "chinese", "indian", "how", "code", "it", "post", "cherry", "house", "hinton", "select", "range", "european", "have", "type", "moderately", "serves", "nandos", "pizza", "postcode", "c.b", "priced", "royal", "no", "asian", "there", "cambridge", "anything", "thanh", "binh", "italian", "hut", "tandoori", "oriental", "else", "missing", "sock", "chesterton", "dontcare", "get", "spice", "pizzeria", "da", "vinci", "margherita", "korean", "serving", "nirala", "lucky", "star", "fen", "ditton", "saint", "noodle", "hotel", "rajmahal", "chop", "british", "please", "johns", "meghna", "seoul", "serve", "uh", "newmarket", "little", "to", "want", "park", "vietnamese", "international", "curry", "spanish", "leisure", "portuguese", "turkish", "am", "do", "garden", "need", "-", "like", "find", "okay", "reqmore", "clifton", "way", "polynesian", "golden", "saigon", "alimentum", "two", "yu", "bistro", "canthelp.exception", "cote", "american", "prezzo", "yippee", "french", "should", "doesn't", "matter", "raza", "bloomsbury", "kitchen", "um", "tasca", "peking", "modern", "2", "lodge", "taj", "pub", "not", "english", "their", "gastropub", "4", "sitar", "wok", "1", "chiquito", "grafton", "corsica", "standard", "greek", "thai", "sala", "thong", "may", "cafe", "bridge", "king", "hi", "milton", "lebanese", "one", "mediterranean", "bennys", "victoria", "pipasha", "regent", "gourmet", "burger", "du", "vin", "luck", "frankie", "steakhouse", "halal", "they", "where", "takeaway", "confirm-domain", "327908"], "y": [2448, 2039, 1997, 1794, 1253, 1085, 830, 775, 723, 631, 631, 597, 523, 506, 478, 474, 423, 416, 399, 388, 366, 348, 327, 327, 320, 317, 316, 304, 295, 291, 279, 276, 272, 269, 266, 263, 256, 219, 218, 217, 214, 213, 200, 199, 187, 158, 156, 150, 150, 145, 145, 144, 143, 140, 137, 133, 132, 128, 125, 121, 121, 121, 120, 119, 111, 110, 109, 106, 103, 103, 102, 100, 100, 98, 98, 96, 95, 95, 90, 89, 89, 88, 87, 86, 81, 79, 79, 78, 76, 73, 73, 73, 72, 72, 68, 67, 65, 63, 63, 61, 61, 61, 60, 60, 59, 59, 59, 58, 58, 58, 58, 57, 55, 55, 55, 53, 51, 50, 50, 50, 50, 49, 49, 48, 48, 48, 47, 46, 45, 45, 45, 45, 44, 43, 42, 42, 41, 41, 40, 40, 40, 40, 40, 40, 40, 39, 39, 39, 38, 38, 36, 35, 35, 35, 35, 34, 34, 33, 32, 32, 32, 32, 32, 31, 31, 30, 29, 29, 29, 28, 28, 28, 28, 27, 27, 26, 26, 26, 26, 26, 26, 26, 26, 25, 25, 25, 25, 24, 24, 24, 24, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 21, 21, 21, 21, 21], "type": "bar", "uid": "5e2d2b99-9841-46ed-af79-05c18f4fd1f7"}], {"margin": {"b": 150}, "title": "<b>Dev tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#3498db"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#3498db"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("598d83d8-9e1f-4e45-a167-00829ab0a1a7"));});</script>
# INFO:root:Dev top tokens:	[('inform', 2448), ('name', 2039), ('offer', 1997), ('food', 1794), ('the', 1253), ('area', 1085), ('pricerange', 830), ('phone', 775), ('restaurant', 723), ('request', 631), ('slot', 631)]

# %%
test_X_axis = []
test_Y_axis = []
test_top_tokens = []
sorted_dict = sorted(test_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(test_top_tokens) <= 10:
        test_top_tokens.append((token, token_count))
    if token_count > 40:
        test_X_axis.append(token)
        test_Y_axis.append(token_count)

assert(len(test_X_axis) == len(test_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = test_X_axis,
                 y = test_Y_axis,
                 marker = dict(color = "#9b59b6"))],
    "layout": Layout(title = "<b>Test tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#9b59b6")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#9b59b6")),
                     margin = plotly.graph_objs.layout.Margin(b = 150)
                    )
})


logging.info("Test top tokens:\t{}".format(test_top_tokens))
# Out:
# <div id="9bab409d-2499-46e5-9545-ff12c6274f62" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9bab409d-2499-46e5-9545-ff12c6274f62", [{"marker": {"color": "#9b59b6"}, "orientation": "v", "x": ["inform", "food", "name", "offer", "area", "the", "pricerange", "request", "slot", "impl-conf", "phone", "restaurant", "you", "count", "thank", "welcomemsg", "i", "canthelp", "expl-conf", "number", "of", "address", "cheap", "moderate", "addr", "a", "01223", "and", "goodbye", "dontcare", "south", "in", "expensive", "centre", "what", "part", "town", "is", "east", "for", "north", "looking", "yes", "repeat", "i'm", "west", "don't", "good", "care", "bye", "city", "chinese", "what's", "any", "about", "2", "that", "can", "ok", "street", "european", "road", "no", "italian", "la", "indian", "how", "bar", "cherry", "code", "price", "hinton", "post", "moderately", "pizza", "serves", "priced", "it", "reqmore", "have", "postcode", "c.b", "nandos", "range", "asian", "spanish", "there", "oriental", "portuguese", "hut", "cambridge", "vietnamese", "thanh", "binh", "type", "3", "5", "anything", "turkish", "missing", "sock", "else", "korean", "want", "canthelp.exception", "royal", "matter", "british", "doesn't", "hotel", "mediterranean", "little", "fen", "ditton", "seoul", "pizzeria", "tandoori", "international", "house", "da", "vinci", "star", "lucky", "chesterton", "park", "gastropub", "4", "please", "saint", "leisure", "serving", "to", "okay", "french", "9", "need", "uh", "margherita", "thai", "yu", "garden", "bistro", "um", "like", "way", "31", "clifton", "hi", "spice", "chop", "alimentum", "newmarket", "22", "get", "prezzo", "johns", "kitchen", "grafton", "rajmahal", "two", "noodle", "nirala", "am", "-", "tasca", "find", "curry", "not", "meghna", "chiquito", "serve", "raza", "sitar", "golden", "modern", "wok", "peking", "pub", "irish", "bennys", "do", "prince", "regent", "frankie", "cantonese", "their", "1", "cow", "standard", "me", "malaysian", "cafe", "english", "canapes", "saigon", "15", "milton", "christmas", "magdalene", "should", "du", "vin", "where", "danish", "yippee", "an", "would", "greek", "galleria", "world", "17", "persian", "mimosa", "does", "lodge", "24", "bloomsbury", "yeah", "luck", "takeaway", "323737", "bridge", "57", "taj", "thong"], "y": [6188, 5768, 3978, 3824, 2941, 2681, 2307, 2174, 2174, 1872, 1765, 1686, 1303, 1213, 1167, 1117, 1092, 1038, 998, 981, 916, 883, 861, 788, 772, 764, 749, 732, 723, 721, 713, 709, 700, 691, 683, 635, 629, 621, 620, 595, 581, 570, 543, 527, 485, 479, 469, 465, 431, 424, 403, 387, 384, 383, 370, 360, 340, 328, 322, 315, 310, 303, 300, 298, 289, 285, 276, 274, 267, 262, 262, 257, 254, 254, 253, 247, 234, 222, 220, 216, 205, 205, 200, 197, 194, 191, 190, 185, 184, 183, 183, 175, 175, 175, 175, 174, 171, 170, 164, 163, 163, 159, 156, 153, 151, 149, 148, 146, 144, 143, 140, 139, 138, 138, 137, 136, 133, 133, 131, 128, 128, 126, 125, 122, 122, 119, 117, 114, 112, 111, 110, 109, 106, 106, 105, 105, 104, 104, 104, 103, 103, 100, 99, 99, 99, 98, 98, 97, 97, 96, 95, 94, 93, 90, 89, 88, 85, 83, 82, 81, 79, 78, 76, 76, 75, 74, 72, 71, 71, 68, 67, 67, 64, 61, 60, 59, 59, 58, 58, 58, 58, 58, 58, 57, 57, 56, 56, 53, 52, 51, 51, 50, 50, 49, 48, 47, 47, 47, 46, 46, 46, 46, 46, 46, 46, 45, 45, 45, 45, 45, 44, 44, 44, 43, 43, 43, 43, 42, 42, 42, 42, 42, 41, 41, 41], "type": "bar", "uid": "4e79543b-6cce-412f-8907-791d4dc3d9f8"}], {"margin": {"b": 150}, "title": "<b>Test tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#9b59b6"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#9b59b6"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){windo ...
# INFO:root:Test top tokens:	[('inform', 6188), ('food', 5768), ('name', 3978), ('offer', 3824), ('area', 2941), ('the', 2681), ('pricerange', 2307), ('request', 2174), ('slot', 2174), ('impl-conf', 1872), ('phone', 1765)]

# %%
train_dev_oov_tokens = []

for token, count in dev_vocabulary.items():
    if token not in train_vocabulary:
        if token not in train_dev_oov_tokens:
            train_dev_oov_tokens.append(token)

train_dev_oov_rate = len(train_dev_oov_tokens)/len(dev_vocabulary)

logging.info("Train-Dev OOV rate:\t{}".format(train_dev_oov_rate))
logging.info("Train-Dev OOV tokens:\t{}".format(train_dev_oov_tokens))
# Out:
# INFO:root:Train-Dev OOV rate:	0.10894941634241245
# INFO:root:Train-Dev OOV tokens:	['allowed', 'quarter', 'venue', 'such', 'essentially', 'best', 'twenty', 'search', 'touch', 'move', 'typical', 'direct', 'comments', "couldn't", "won't", 'noon', 'alone', 'americas', 'recognised', 'drink', 'clowns', '324351', 'nice', 'eclectic', 'third', 'found', 'worry', 'twelve', 'global', 'club', 'hold', 'drop', 'affordable', 'helpful', 'miles', 'available', '52', 'ranges', 'connection', 'brb', 'goes', "you're", 'point', 'mentioned', 'below', 'behind', 'cuisine', 'seen', 'answer', 'pitch', 'recommend', 'eleven', 'tight', 'children', "you've", 'exact', 'theme', 'content', 'has', 'lasts', 'football', 'come', 'piece', 'true', 'seem', 'around', 'g', 'zealand', 'intermediate', 'cars', 'tour', 'tells', 'arrange', 'stores', 'info', 'still', 'shows', '355711', 'areas', 'meet', 'super', 'small', 'thing', 'signature']

# %%
train_test_oov_tokens = []

for token, count in test_vocabulary.items():
    if token not in train_vocabulary:
        if token not in train_test_oov_tokens:
            train_test_oov_tokens.append(token)

train_test_oov_rate = len(train_test_oov_tokens)/len(test_vocabulary)

logging.info("Train-Test OOV rate:\t{}".format(train_test_oov_rate))
logging.info("Train-Test OOV tokens:\t{}".format(train_test_oov_tokens))
# Out:
# INFO:root:Train-Test OOV rate:	0.16575192096597147
# INFO:root:Train-Test OOV tokens:	['count', 'directly', '9', 'tight', "won't", '109', 'fare', '57', "benny's", 'spend', 'includes', 'essentially', 'quickly', 'excuse', '69', 'make', 'suggestions', 'ho', 'eight', 'spent', 'spain', 'still', 'seen', 'up', 'county', "you're", 'p', 'such', 'meal', 'books', 'dear', 'third', 'storey', 'wow', 'advice', 'confirm', 'salad', 'comment', 'remember', 'h', 'nice', 'stops', 'useless', 'found', 'connect', 'cheapest', 'longer', 'kinds', 'itself', 'reference', 'tomorrow', 'continues', "aren't", 'signature', 'thru', 'fill', 'pool', 'union', 'twenty', '110', 'has', '56', 'movies', 'forty', 'helpful', 'hate', 'seem', 'names', 'pig', 'quick', 'straight', 'checking', 'beers', 'collecting', 'continue', 'nothing', 'feature', 'selling', 'sheet', 'public', 'walk', 'charging', "didn't", 'man', 'into', 'going', 'suggest', 'global', 'current', 'smallish', 'special', 'open', 'move', 'onto', 'snack', 'lunch', "we're", 'preference', 'cars', 'downwards', 'clearly', 'porsche', 'pools', 'search', 'jesus', 'details', 'field', 'tourists', "they've", 'assuming', 'actual', 'apart', 'available', 'highest', 'inclined', '52', 'clowns', 'front', 'helps', 'costly', 'expect', 'usually', '355711', 'eclectic', 'seeing', 'point', 'come', 'already', 'gonna', 'around', 'reform', 'applies', 'answer', 'small', 'football', 'club', 'vary', 'able', 'ever', 'finished', 'us', 't', 'ranges', 'interested', 'bit', 'arrange', 'popular', 'rang', 'recommend', "couldn't", 'areas']
