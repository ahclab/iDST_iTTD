# %%
import numpy as np
import plotly
import logging
logging.getLogger().setLevel(logging.INFO)

from idst_util import trivial
from idst_util import dstc2
from operator import itemgetter
from plotly.graph_objs import Bar, Layout
from plotly.graph_objs.layout import Margin
plotly.offline.init_notebook_mode(connected = True)
# Out:
# [nltk_data] Downloading package punkt to /home/is/andrei-
# [nltk_data]     cc/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# Make sure data is available
trivial.print_idst()
dstc2.check()

# Retrieve raw data
raw_X_train, raw_Y_train, \
raw_X_dev, raw_Y_dev, \
raw_X_test, raw_Y_test, \
ontology = dstc2.retrieve_raw_datasets(train_data_augmentation = False)
# Out:
# INFO:root:+--------------------------------+
# INFO:root:|         _ ____  ___________    |
# INFO:root:|        (_) __ \/ ___/_  __/    |
# INFO:root:|       / / / / /\__ \ / /       |
# INFO:root:|      / / /_/ /___/ // /        |
# INFO:root:|     /_/_____//____//_/         |
# INFO:root:|                                |
# INFO:root:+--------------------------------+
# INFO:root:|Incremental Dialog State Tracker|
# INFO:root:+--------------------------------+
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|         Data Checker           |
# INFO:root:+--------------------------------+
# INFO:root:Looking for dstc2 directory in .
# INFO:root:dstc2 was found!
# INFO:root:Looking for dstc2_traindev directory in ./dstc2
# INFO:root:dstc2_traindev was found!
# INFO:root:Looking for dstc2_test directory in ./dstc2
# INFO:root:dstc2_test was found!
# INFO:root:Looking for dstc2_scripts directory in ./dstc2
# INFO:root:dstc2_scripts was found!
# INFO:root:Done!
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|       Dataset Retrieval        |
# INFO:root:+--------------------------------+
# INFO:root:Reading dstc2_train.flist, dstc2_dev.flist and ontology_dstc2.json
# INFO:root:Asserted 1612 dialogs for dstc2_train.flist
# INFO:root:Asserted 506 dialogs for dstc2_dev.flist
# INFO:root:Extracting raw train features
# 100%|██████████| 1612/1612 [00:08<00:00, 191.23it/s]
# INFO:root:Extracting raw dev features
# 100%|██████████| 506/506 [00:02<00:00, 175.94it/s]
# INFO:root:Reading dstc2_test.flist
# INFO:root:Asserted 1117 dialogs for dstc2_test.flist
# INFO:root:Extracting raw test features
# 100%|██████████| 1117/1117 [00:07<00:00, 155.88it/s]

# %%
def retrieve_info(raw_X):
    
    token_to_count = {}
    max_sequence_length = 0
    turns_list = []
    
    for raw_dialog in raw_X:
        turns_count = 0
        for raw_turn in raw_dialog["turns"]:
            turns_count += 1
            current_sequence_length = len(raw_turn["system"]) + len(raw_turn["user"])
            if current_sequence_length > max_sequence_length:
                max_sequence_length = current_sequence_length

            for system_token in raw_turn["system"]:
                token = system_token[0]
                if token not in token_to_count:
                    token_to_count[token] = 1
                else:
                    token_to_count[token] += 1

            for user_token in raw_turn["user"]:
                token = user_token[0]
                if token not in token_to_count:
                    token_to_count[token] = 1
                else:
                    token_to_count[token] += 1
            turns_list.append(turns_count)
    
    return token_to_count, max_sequence_length, np.mean(turns_list)

# %%
train_vocabulary, \
train_max_sequence_length, \
train_average_turns_per_dialog = retrieve_info(raw_X_train)


dev_vocabulary, \
dev_max_sequence_length, \
dev_average_turns_per_dialog = retrieve_info(raw_X_dev)

test_vocabulary, \
test_max_sequence_length, \
test_average_turns_per_dialog = retrieve_info(raw_X_test)

# %%
logging.info("+--------------------------------+")
logging.info("|     Dialog State Tracker 2     |")
logging.info("|         Data Analysis          |")
logging.info("+--------------------------------+\n")

logging.info("Train number of dialogs:\t{}".format(len(raw_X_train)))
logging.info("Train vocabulary length:\t{}".format(len(train_vocabulary)))
logging.info("Train max sequence length:\t{}".format(train_max_sequence_length))
logging.info("Train average turns:\t\t{}\n".format(train_average_turns_per_dialog))

logging.info("Dev number of dialogs:\t{}".format(len(raw_X_dev)))
logging.info("Dev vocabulary length:\t{}".format(len(dev_vocabulary)))
logging.info("Dev max sequence length:\t{}".format(dev_max_sequence_length))
logging.info("Dev average turns:\t\t{}\n".format(dev_average_turns_per_dialog))

logging.info("Test number of dialogs:\t{}".format(len(raw_X_test)))
logging.info("Test vocabulary length:\t{}".format(len(test_vocabulary)))
logging.info("Test max sequence length:\t{}".format(test_max_sequence_length))
logging.info("Test average turns:\t\t{}\n".format(test_average_turns_per_dialog))
# Out:
# INFO:root:+--------------------------------+
# INFO:root:|     Dialog State Tracker 2     |
# INFO:root:|         Data Analysis          |
# INFO:root:+--------------------------------+
#
# INFO:root:Train number of dialogs:	1612
# INFO:root:Train vocabulary length:	922
# INFO:root:Train max sequence length:	28
# INFO:root:Train average turns:		4.930461591162113
#
# INFO:root:Dev number of dialogs:	506
# INFO:root:Dev vocabulary length:	764
# INFO:root:Dev max sequence length:	28
# INFO:root:Dev average turns:		5.454499237417387
#
# INFO:root:Test number of dialogs:	1117
# INFO:root:Test vocabulary length:	901
# INFO:root:Test max sequence length:	34
# INFO:root:Test average turns:		5.983923154701719

# %%
train_X_axis = []
train_Y_axis = []
train_top_tokens = []
sorted_dict = sorted(train_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(train_top_tokens) <= 10:
        train_top_tokens.append((token, token_count))
    if token_count > 50:
        train_X_axis.append(token)
        train_Y_axis.append(token_count)

assert(len(train_X_axis) == len(train_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = train_X_axis,
                 y = train_Y_axis,
                 marker = dict(color = "#1abc9c"))],
    "layout": Layout(title = "<b>Train tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#1abc9c")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#1abc9c")),
                     margin = Margin(b = 150)
                    )
})

logging.info("Train top tokens:\t{}".format(train_top_tokens))
# Out:
# <div id="8cd97e6d-44ad-492f-bb52-b571378372fd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8cd97e6d-44ad-492f-bb52-b571378372fd", [{"marker": {"color": "#1abc9c"}, "orientation": "v", "x": ["inform", "name", "offer", "food", "the", "area", "pricerange", "phone", "restaurant", "request", "slot", "i", "you", "thank", "welcomemsg", "what", "number", "canthelp", "address", "addr", "of", "cheap", "01223", "goodbye", "a", "and", "expensive", "centre", "moderate", "in", "north", "is", "south", "part", "town", "for", "looking", "west", "east", "good", "'s", "city", "n't", "'m", "bye", "do", "that", "expl-conf", "road", "about", "can", "street", "bar", "care", "chinese", "indian", "yes", "cherry", "any", "hinton", "pizza", "post", "serves", "code", "ok", "moderately", "how", "european", "price", "have", "la", "cambridge", "priced", "postcode", "c.b", "it", "hut", "royal", "house", "there", "anything", "type", "thanh", "binh", "italian", "else", "range", "select", "nandos", "does", "fen", "ditton", "chesterton", "pizzeria", "want", "tandoori", "okay", "saint", "missing", "sock", "da", "vinci", "no", "british", "two", "spice", "asian", "curry", "park", "chop", "little", "johns", "uh", "hotel", "lucky", "star", "matter", "dontcare", "please", "seoul", "prezzo", "turkish", "like", "golden", "oriental", "leisure", "korean", "to", "alimentum", "meghna", "chiquito", "wok", "kitchen", "newmarket", "vietnamese", "portuguese", "garden", "french", "-", "clifton", "way", "2", "prince", "margherita", "serve", "find", "bistro", "spanish", "modern", "thai", "international", "noodle", "mediterranean", "sala", "thong", "hi", "grafton", "um", "peking", "gastropub", "serving", "rajmahal", "cafe", "nirala", "yu", "standard", "frankie", "bennys", "michaelhouse", "need", "am", "get", "tasca", "1", "lodge", "regent", "kind", "reqmore", "canthelp.exception", "confirm-domain", "greek", "24", "gourmet", "burger", "saigon", "world", "american", "luck", "takeaway", "would", "sitar", "anatolia", "bridge", "pipasha", "cote", "an", "taj", "cow", "victoria", "raza", "21", "meze", "magdalene", "northampton", "fusion", "mexican", "cantonese", "may", "milton", "'d", "gardenia", "mill", "wagamama", "bangkok", "could", "not", "corsica", "me", "danish", "english", "their", "pub", "varsity"], "y": [7936, 6162, 6077, 5331, 3596, 3261, 2584, 2571, 2353, 1910, 1910, 1904, 1844, 1640, 1612, 1501, 1402, 1286, 1258, 1168, 1139, 1128, 1108, 1039, 999, 992, 949, 923, 917, 898, 867, 844, 804, 760, 754, 746, 731, 698, 668, 661, 650, 619, 616, 611, 598, 522, 516, 505, 501, 484, 455, 445, 434, 421, 399, 387, 384, 369, 354, 354, 350, 347, 346, 343, 336, 331, 328, 325, 315, 312, 308, 307, 298, 296, 296, 294, 272, 270, 267, 258, 255, 255, 253, 253, 248, 247, 240, 240, 238, 234, 225, 225, 216, 216, 204, 202, 196, 195, 195, 195, 194, 192, 187, 186, 182, 181, 180, 180, 176, 173, 169, 169, 168, 164, 162, 162, 161, 161, 161, 160, 160, 157, 156, 156, 154, 154, 150, 148, 147, 141, 139, 139, 138, 133, 133, 131, 129, 128, 126, 125, 125, 124, 122, 118, 117, 115, 115, 114, 114, 112, 105, 104, 104, 101, 101, 101, 100, 98, 97, 96, 96, 93, 92, 92, 89, 89, 88, 88, 88, 87, 87, 83, 81, 81, 81, 80, 80, 79, 79, 78, 78, 75, 75, 75, 74, 73, 73, 73, 73, 69, 68, 68, 67, 66, 65, 64, 63, 63, 62, 61, 61, 61, 60, 60, 60, 59, 58, 58, 56, 56, 55, 55, 55, 55, 54, 54, 54, 53, 53, 52, 52, 52, 52], "type": "bar", "uid": "582142b0-5fd3-4cc5-8c59-0b02881f2830"}], {"margin": {"b": 150}, "title": "<b>Train tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#1abc9c"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#1abc9c"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventL ...
# INFO:root:Train top tokens:	[('inform', 7936), ('name', 6162), ('offer', 6077), ('food', 5331), ('the', 3596), ('area', 3261), ('pricerange', 2584), ('phone', 2571), ('restaurant', 2353), ('request', 1910), ('slot', 1910)]

# %%
dev_X_axis = []
dev_Y_axis = []
dev_top_tokens = []
sorted_dict = sorted(dev_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(dev_top_tokens) <= 10:
        dev_top_tokens.append((token, token_count))
    if token_count > 20:
        dev_X_axis.append(token)
        dev_Y_axis.append(token_count)

assert(len(dev_X_axis) == len(dev_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = dev_X_axis,
                 y = dev_Y_axis,
                 marker = dict(color = "#3498db"))],
    "layout": Layout(title = "<b>Dev tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#3498db")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#3498db")),
                     margin = Margin(b = 150)
                    )
})


logging.info("Dev top tokens:\t{}".format(dev_top_tokens))
# Out:
# <div id="9e418553-0dcc-4488-bb30-bd39b2724739" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e418553-0dcc-4488-bb30-bd39b2724739", [{"marker": {"color": "#3498db"}, "orientation": "v", "x": ["inform", "name", "offer", "food", "the", "area", "pricerange", "phone", "restaurant", "i", "request", "slot", "you", "thank", "welcomemsg", "canthelp", "what", "number", "of", "cheap", "address", "addr", "and", "is", "01223", "goodbye", "a", "in", "north", "centre", "town", "part", "expensive", "for", "moderate", "south", "looking", "east", "good", "west", "city", "'m", "expl-conf", "bye", "do", "n't", "can", "'s", "any", "road", "that", "yes", "street", "ok", "about", "price", "la", "bar", "care", "chinese", "it", "indian", "how", "code", "post", "cherry", "house", "hinton", "select", "range", "european", "have", "type", "moderately", "serves", "nandos", "pizza", "postcode", "c.b", "priced", "royal", "there", "no", "asian", "cambridge", "anything", "thanh", "binh", "italian", "hut", "tandoori", "oriental", "else", "missing", "sock", "chesterton", "dontcare", "get", "spice", "pizzeria", "da", "vinci", "margherita", "korean", "serving", "nirala", "lucky", "star", "fen", "ditton", "saint", "noodle", "hotel", "rajmahal", "chop", "british", "please", "does", "johns", "meghna", "seoul", "serve", "uh", "newmarket", "little", "to", "want", "park", "vietnamese", "international", "curry", "spanish", "leisure", "portuguese", "turkish", "am", "garden", "need", "-", "like", "find", "okay", "reqmore", "clifton", "way", "polynesian", "golden", "saigon", "alimentum", "two", "yu", "bistro", "canthelp.exception", "cote", "american", "prezzo", "yippee", "french", "should", "matter", "raza", "bloomsbury", "kitchen", "um", "tasca", "peking", "modern", "2", "lodge", "taj", "pub", "not", "english", "their", "gastropub", "4", "sitar", "wok", "1", "chiquito", "grafton", "corsica", "standard", "greek", "thai", "sala", "thong", "may", "cafe", "bridge", "king", "hi", "milton", "lebanese", "one", "mediterranean", "bennys", "victoria", "pipasha", "regent", "where", "gourmet", "burger", "du", "vin", "luck", "frankie", "steakhouse", "halal", "they", "takeaway", "confirm-domain", "327908"], "y": [2448, 2039, 1997, 1794, 1253, 1085, 830, 775, 723, 701, 631, 631, 604, 523, 506, 478, 475, 423, 416, 399, 388, 366, 348, 327, 327, 320, 316, 304, 295, 291, 279, 276, 272, 269, 266, 263, 256, 219, 218, 217, 214, 213, 200, 199, 198, 191, 187, 180, 150, 150, 147, 145, 145, 144, 143, 140, 137, 133, 128, 125, 122, 121, 121, 121, 119, 111, 110, 109, 106, 103, 103, 102, 100, 100, 98, 98, 96, 95, 95, 90, 89, 89, 89, 88, 86, 81, 79, 79, 78, 76, 73, 73, 73, 72, 72, 68, 67, 65, 63, 63, 61, 61, 61, 60, 60, 59, 59, 59, 58, 58, 58, 58, 57, 55, 55, 55, 53, 52, 51, 50, 50, 50, 50, 49, 49, 48, 48, 48, 47, 46, 45, 45, 45, 45, 44, 43, 42, 41, 41, 40, 40, 40, 40, 40, 40, 40, 39, 39, 39, 38, 38, 36, 35, 35, 35, 35, 34, 34, 33, 32, 32, 32, 32, 31, 31, 30, 29, 29, 29, 28, 28, 28, 28, 27, 27, 26, 26, 26, 26, 26, 26, 26, 26, 25, 25, 25, 25, 24, 24, 24, 24, 23, 23, 23, 23, 23, 23, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 21, 21, 21, 21], "type": "bar", "uid": "4ab07152-d582-4ea8-9540-05506e8ad242"}], {"margin": {"b": 150}, "title": "<b>Dev tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#3498db"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#3498db"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("9e418553-0dcc-4488-bb30-bd39b2724739"));});</script>
# INFO:root:Dev top tokens:	[('inform', 2448), ('name', 2039), ('offer', 1997), ('food', 1794), ('the', 1253), ('area', 1085), ('pricerange', 830), ('phone', 775), ('restaurant', 723), ('i', 701), ('request', 631)]

# %%
test_X_axis = []
test_Y_axis = []
test_top_tokens = []
sorted_dict = sorted(test_vocabulary.items(), key = itemgetter(1), reverse = True)

for token, token_count in sorted_dict:
    if len(test_top_tokens) <= 10:
        test_top_tokens.append((token, token_count))
    if token_count > 40:
        test_X_axis.append(token)
        test_Y_axis.append(token_count)

assert(len(test_X_axis) == len(test_Y_axis)) 

plotly.offline.iplot({
    "data": [Bar(orientation = "v",
                 x = test_X_axis,
                 y = test_Y_axis,
                 marker = dict(color = "#9b59b6"))],
    "layout": Layout(title = "<b>Test tokens distribution</b>",
                     xaxis = dict(title = "<b>Tokens</b>", dtick = 3, titlefont = dict(color = "#9b59b6")),
                     yaxis = dict(title = "<b>Frequency</b>", titlefont = dict(color = "#9b59b6")),
                     margin = Margin(b = 150)
                    )
})


logging.info("Test top tokens:\t{}".format(test_top_tokens))
# Out:
# <div id="faec0032-de23-41ce-96e6-11a8cce05cef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("faec0032-de23-41ce-96e6-11a8cce05cef", [{"marker": {"color": "#9b59b6"}, "orientation": "v", "x": ["inform", "food", "name", "offer", "area", "the", "pricerange", "request", "slot", "impl-conf", "phone", "restaurant", "i", "you", "count", "thank", "welcomemsg", "what", "canthelp", "expl-conf", "number", "of", "address", "cheap", "moderate", "addr", "a", "01223", "and", "goodbye", "dontcare", "south", "in", "expensive", "centre", "part", "town", "is", "n't", "east", "for", "north", "looking", "yes", "repeat", "do", "'m", "west", "good", "'s", "care", "bye", "city", "chinese", "any", "that", "about", "2", "can", "ok", "street", "european", "road", "no", "italian", "la", "indian", "how", "bar", "cherry", "code", "price", "hinton", "post", "moderately", "pizza", "serves", "priced", "it", "reqmore", "have", "postcode", "c.b", "nandos", "range", "asian", "there", "spanish", "does", "oriental", "portuguese", "hut", "cambridge", "vietnamese", "thanh", "binh", "type", "3", "5", "anything", "turkish", "missing", "sock", "else", "korean", "want", "canthelp.exception", "royal", "matter", "british", "hotel", "mediterranean", "little", "fen", "ditton", "seoul", "pizzeria", "tandoori", "international", "house", "da", "vinci", "star", "lucky", "chesterton", "park", "gastropub", "4", "please", "saint", "leisure", "serving", "to", "okay", "french", "9", "need", "uh", "margherita", "thai", "yu", "garden", "bistro", "um", "like", "way", "31", "clifton", "hi", "spice", "chop", "alimentum", "newmarket", "22", "get", "prezzo", "johns", "kitchen", "grafton", "rajmahal", "two", "noodle", "nirala", "am", "-", "tasca", "find", "not", "curry", "meghna", "chiquito", "serve", "raza", "sitar", "golden", "modern", "wok", "peking", "pub", "irish", "bennys", "prince", "regent", "frankie", "cantonese", "their", "1", "cow", "standard", "me", "malaysian", "cafe", "english", "canapes", "where", "saigon", "15", "milton", "christmas", "magdalene", "should", "du", "vin", "danish", "yippee", "an", "would", "greek", "galleria", "world", "17", "persian", "mimosa", "lodge", "24", "bloomsbury", "yeah", "luck", "takeaway", "323737", "bridge", "could", "57", "taj", "thong"], "y": [6188, 5768, 3978, 3824, 2941, 2681, 2307, 2174, 2174, 1872, 1765, 1686, 1611, 1322, 1213, 1167, 1117, 1067, 1038, 998, 981, 916, 883, 861, 788, 772, 764, 749, 732, 723, 721, 713, 709, 700, 691, 635, 629, 621, 620, 620, 595, 581, 570, 543, 527, 527, 485, 479, 465, 436, 431, 424, 403, 387, 383, 378, 370, 360, 330, 322, 315, 310, 303, 300, 298, 289, 285, 276, 274, 267, 262, 262, 257, 254, 254, 253, 247, 234, 223, 220, 216, 205, 205, 200, 197, 194, 193, 191, 187, 185, 184, 183, 183, 175, 175, 175, 175, 174, 171, 170, 164, 163, 163, 159, 156, 153, 151, 149, 148, 146, 143, 140, 139, 138, 138, 137, 136, 133, 133, 131, 128, 128, 126, 125, 122, 122, 119, 117, 114, 112, 111, 110, 109, 106, 106, 105, 105, 104, 104, 104, 103, 103, 100, 99, 99, 99, 98, 98, 97, 97, 96, 95, 94, 93, 90, 89, 88, 85, 83, 82, 81, 79, 78, 76, 76, 75, 74, 73, 72, 71, 68, 67, 67, 64, 61, 60, 59, 59, 58, 58, 58, 58, 58, 57, 57, 56, 56, 53, 52, 51, 51, 50, 50, 49, 48, 48, 47, 47, 47, 46, 46, 46, 46, 46, 46, 45, 45, 45, 45, 45, 44, 44, 44, 43, 43, 43, 42, 42, 42, 42, 42, 41, 41, 41, 41], "type": "bar", "uid": "a6d79255-4c9a-461d-a60e-65b8ebb529a0"}], {"margin": {"b": 150}, "title": "<b>Test tokens distribution</b>", "xaxis": {"dtick": 3, "title": "<b>Tokens</b>", "titlefont": {"color": "#9b59b6"}}, "yaxis": {"title": "<b>Frequency</b>", "titlefont": {"color": "#9b59b6"}}}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plot ...
# INFO:root:Test top tokens:	[('inform', 6188), ('food', 5768), ('name', 3978), ('offer', 3824), ('area', 2941), ('the', 2681), ('pricerange', 2307), ('request', 2174), ('slot', 2174), ('impl-conf', 1872), ('phone', 1765)]

# %%
train_dev_oov_tokens = []

for token, count in dev_vocabulary.items():
    if token not in train_vocabulary:
        if token not in train_dev_oov_tokens:
            train_dev_oov_tokens.append(token)

train_dev_oov_rate = len(train_dev_oov_tokens)/len(dev_vocabulary)

logging.info("Train-Dev OOV rate:\t{}".format(train_dev_oov_rate))
logging.info("Train-Dev OOV tokens:\t{}".format(train_dev_oov_tokens))
# Out:
# INFO:root:Train-Dev OOV rate:	0.10863874345549739
# INFO:root:Train-Dev OOV tokens:	['allowed', 'quarter', 'venue', 'such', 'essentially', 'best', 'twenty', 'search', 'touch', 'move', 'typical', 'direct', 'comments', 'wo', 'noon', 'alone', 'americas', 'recognised', 'drink', 'clowns', '324351', 'nice', 'eclectic', 'third', 'found', 'worry', 'twelve', 'global', 'club', 'hold', 'drop', 'affordable', 'helpful', 'miles', 'available', '52', 'ranges', 'connection', 'brb', 'goes', "'re", 'point', 'mentioned', 'below', 'behind', 'cuisine', 'seen', 'answer', 'pitch', 'recommend', 'eleven', 'tight', 'children', "'ve", 'exact', 'theme', 'content', 'has', 'lasts', 'football', 'come', 'piece', 'true', 'seem', 'around', 'g', 'zealand', 'intermediate', 'cars', 'tour', 'tells', 'arrange', 'stores', 'info', 'still', 'shows', '355711', 'areas', 'meet', 'super', 'small', 'thing', 'signature']

# %%
train_test_oov_tokens = []

for token, count in test_vocabulary.items():
    if token not in train_vocabulary:
        if token not in train_test_oov_tokens:
            train_test_oov_tokens.append(token)

train_test_oov_rate = len(train_test_oov_tokens)/len(test_vocabulary)

logging.info("Train-Test OOV rate:\t{}".format(train_test_oov_rate))
logging.info("Train-Test OOV tokens:\t{}".format(train_test_oov_tokens))
# Out:
# INFO:root:Train-Test OOV rate:	0.16315205327413984
# INFO:root:Train-Test OOV tokens:	['count', 'directly', '9', 'tight', 'wo', '109', 'fare', '57', 'benny', 'spend', 'includes', 'essentially', 'quickly', 'excuse', '69', 'make', 'suggestions', 'ho', 'eight', 'spent', 'spain', 'still', 'seen', 'up', 'county', "'re", 'p', 'such', 'meal', 'books', 'dear', 'third', 'storey', 'wow', 'advice', 'confirm', 'salad', 'comment', 'remember', 'h', 'nice', 'stops', 'useless', 'found', 'connect', 'cheapest', 'longer', 'kinds', 'itself', 'reference', 'tomorrow', 'continues', 'signature', 'thru', 'fill', 'pool', 'union', 'twenty', '110', 'has', '56', 'movies', 'forty', 'helpful', 'hate', 'seem', 'names', 'pig', 'quick', 'straight', 'checking', 'beers', 'collecting', 'continue', 'nothing', 'feature', 'selling', 'sheet', 'public', 'walk', 'charging', 'man', 'into', 'going', 'suggest', 'global', 'current', 'smallish', 'special', 'open', 'move', 'onto', 'snack', 'lunch', 'preference', 'cars', 'downwards', 'clearly', 'porsche', 'pools', 'search', 'jesus', 'details', 'field', 'tourists', "'ve", 'assuming', 'actual', 'apart', 'available', 'highest', 'inclined', '52', 'clowns', 'front', 'helps', 'costly', 'expect', 'usually', '355711', 'eclectic', 'seeing', 'point', 'come', 'already', 'gon', 'around', 'reform', 'applies', 'answer', 'small', 'football', 'club', 'vary', 'able', 'ever', 'finished', 'us', 't', 'ranges', 'interested', 'bit', 'arrange', 'popular', 'rang', 'recommend', 'areas']
